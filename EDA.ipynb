# %%
df1=pd.read_csv("EDA.csv")
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1=pd.read_csv("EDA.csv")
#       2 df1
#
# NameError: name 'pd' is not defined

# %%
import numpy as mp
import pandas as pd

# %%
df1=pd.read_csv("EDA.csv")
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df=pd.read_csv("C:/Users/Thanigaivel/Desktop/Data Science/EDA.csv")
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin
# 0      0         A/5 21171   7.2500   NaN
# 1      0          PC 17599  71.2833   C85
# 2      0  STON/O2. 3101282   7.9250   NaN
# 3      0            113803  53.1000  C123
# 4      0            373450   8.0500   NaN

# %%
print(df.tail())
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# 7                     Palsson, Master. Gosta Leonard    male    2      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
#
#    Parch  Ticket     Fare Cabin
# 5      0  330877   8.4583   NaN
# 6      0   17463  51.8625   E46
# 7      1  349909  21.0750   NaN
# 8      2  347742  11.1333   NaN
# 9      0  237736  30.0708    B5

# %%
import pandas as pd

# Assuming df is your DataFrame
print(df.tail())
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# 7                     Palsson, Master. Gosta Leonard    male    2      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
#
#    Parch  Ticket     Fare Cabin
# 5      0  330877   8.4583   NaN
# 6      0   17463  51.8625   E46
# 7      1  349909  21.0750   NaN
# 8      2  347742  11.1333   NaN
# 9      0  237736  30.0708    B5

# %%
df=pd.read_csv("C:/Users/Thanigaivel/Desktop/Data Science/EDA.csv")
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
print(df.tail())
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# 7                     Palsson, Master. Gosta Leonard    male    2      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
#
#    Parch  Ticket     Fare Cabin
# 5      0  330877   8.4583   NaN
# 6      0   17463  51.8625   E46
# 7      1  349909  21.0750   NaN
# 8      2  347742  11.1333   NaN
# 9      0  237736  30.0708    B5

# %%
from tabulate import tabulate

# Assuming df is your DataFrame
print(tabulate(df.tail(), headers='keys', tablefmt='pretty'))
# Out:
# +---+-------------+----------+--------+---------------------------------------------------+--------+-----+-------+-------+--------+---------+-------+
# |   | PassengerId | Survived | Pclass |                       Name                        |  Sex   | Age | SibSp | Parch | Ticket |  Fare   | Cabin |
# +---+-------------+----------+--------+---------------------------------------------------+--------+-----+-------+-------+--------+---------+-------+
# | 5 |      6      |    0     |   3    |                 Moran, Mr. James                  |  male  | 30  |   0   |   0   | 330877 | 8.4583  |  nan  |
# | 6 |      7      |    0     |   1    |              McCarthy, Mr. Timothy J              |  male  | 54  |   0   |   0   | 17463  | 51.8625 |  E46  |
# | 7 |      8      |    0     |   3    |          Palsson, Master. Gosta Leonard           |  male  |  2  |   3   |   1   | 349909 | 21.075  |  nan  |
# ...

# %%
print(df.tail(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df.tail(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin
# 0      0         A/5 21171   7.2500   NaN
# 1      0          PC 17599  71.2833   C85
# 2      0  STON/O2. 3101282   7.9250   NaN
# 3      0            113803  53.1000  C123
# 4      0            373450   8.0500   NaN

# %%
df.tail()
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# 7                     Palsson, Master. Gosta Leonard    male    2      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
#
#    Parch  Ticket     Fare Cabin
# 5      0  330877   8.4583   NaN
# 6      0   17463  51.8625   E46
# 7      1  349909  21.0750   NaN
# 8      2  347742  11.1333   NaN
# 9      0  237736  30.0708    B5

# %%
df.tail(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df.describe()
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count     10.00000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean       5.50000   0.500000   2.300000  28.300000   0.700000   0.300000
# std        3.02765   0.527046   0.948683  14.103191   0.948683   0.674949
# min        1.00000   0.000000   1.000000   2.000000   0.000000   0.000000
# 25%        3.25000   0.000000   1.250000  23.000000   0.000000   0.000000
# 50%        5.50000   0.500000   3.000000  28.500000   0.500000   0.000000
# 75%        7.75000   1.000000   3.000000  35.000000   1.000000   0.000000
# max       10.00000   1.000000   3.000000  54.000000   3.000000   2.000000
#
#             Fare
# count  10.000000
# mean   27.020820
# std    23.601938
# min     7.250000
# 25%     8.152075
# 50%    16.104150
# 75%    46.414575
# max    71.283300

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  10 non-null     int64
#  1   Survived     10 non-null     int64
#  2   Pclass       10 non-null     int64
#  3   Name         10 non-null     object
#  4   Sex          10 non-null     object
#  5   Age          10 non-null     int64
#  6   SibSp        10 non-null     int64
#  7   Parch        10 non-null     int64
#  8   Ticket       10 non-null     object
#  9   Fare         10 non-null     float64
#  10  Cabin        4 non-null      object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 1012.0+ bytes

# %%
df.nunique()
# Out:
# PassengerId    10
# Survived        2
# Pclass          3
# Name           10
# Sex             2
# Age             9
# SibSp           3
# Parch           3
# Ticket         10
# Fare           10
# Cabin           4
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.isnull()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
# 5        False     False   False  False  False  False  False  False   False
# 6        False     False   False  False  False  False  False  False   False
# 7        False     False   False  False  False  False  False  False   False
# 8        False     False   False  False  False  False  False  False   False
# 9        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False   True
# 5  False   True
# ...

# %%
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          6
# dtype: int64

# %%
df["Cabin"].fillna("BBBCC",inplace= True)

# %%
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df.drop(["Cabin"], axis=1,inplace = True)

# %%
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df["Age"].mean()
# Out:
# 28.3

# %%
df["Age"].fillna(df["Age"].mean(),inplace = True)
# Out:
# C:\Users\Thanigaivel\AppData\Local\Temp\ipykernel_153404\1588258379.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace = True)

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
df["Sex"]=df["Sex"].replace("male","Male")
df["Sex"]=df["Sex"].replace("female","Female")
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    Male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female   38      1
# 2                             Heikkinen, Miss. Laina  Female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female   35      1
# 4                           Allen, Mr. William Henry    Male   35      0
# 5                                   Moran, Mr. James    Male   30      0
# 6                            McCarthy, Mr. Timothy J    Male   54      0
# ...

# %%
df['Age']=df['Age'].astype('float')
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    Male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                             Heikkinen, Miss. Laina  Female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                           Allen, Mr. William Henry    Male  35.0      0
# 5                                   Moran, Mr. James    Male  30.0      0
# ...

# %%
df['Age']=df['Age'].astype('int')
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    Male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female   38      1
# 2                             Heikkinen, Miss. Laina  Female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female   35      1
# 4                           Allen, Mr. William Henry    Male   35      0
# 5                                   Moran, Mr. James    Male   30      0
# 6                            McCarthy, Mr. Timothy J    Male   54      0
# ...

# %%
grouped_by = df.groupby("Pclass")
grouped_count = grouped_by["Pclass"].count()
grouped_count
# Out:
# Pclass
# 1    3
# 2    1
# 3    6
# Name: Pclass, dtype: int64

# %%
sur_not = df.groupby(['Survived','Sex'])['PassengerId'].count()
sur_not
# Out:
# Survived  Sex
# 0         Male      5
# 1         Female    5
# Name: PassengerId, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(8, 6))  # Use figsize instead of figSize
sns.barplot(x='Sex', y='Survived', data=df, color='pink', edgecolor='red')
plt.title("Gender vs Survived Rate")
plt.xlabel("Gender")
plt.ylabel("Survived")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Age'],bins=20,color="teal")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 plt.figure(figsize=(8,6))
# ----> 2 sns.histplot(df['Age'],bins=20,color="teal")
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("EDA.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=pd.read_csv("EDA.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
import numpy as mp
import pandas as pd

# %%
df=pd.read_csv("EDA.csv")
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   30      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Age'],bins=20,color="teal",kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(x='Age',y='Fare',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age',y='Fare',data=df,hue=df['Pclass'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age',y='Fare',data=df,hue=df['Pclass'],palette = 'viridis')
plt.title('Relationship between Fare and Age')
# Out:
# Text(0.5, 1.0, 'Relationship between Fare and Age')

# %%
sns.lineplot(x="PassengerId",y='Fare',data=df)
# Out:
# <Axes: xlabel='PassengerId', ylabel='Fare'>
